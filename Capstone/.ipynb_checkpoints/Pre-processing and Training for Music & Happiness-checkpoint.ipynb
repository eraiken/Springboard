# %% [markdown]
# # Pre-processing and Training for Capstone Two: Music & Happiness
#
# ### Table of Contents
#
# * [Introduction](#start)
#     * [Import relevant libraries](#import)
# * [Pre-processing](#preprocess)
#     * [Encode dummy variables for countries](#dummies)
#     * [Scale data using StandardScale](#scaling)
# * [Training](#train)
#     * [Split the data](#split)

# %% [markdown]
# ## 1 - Introduction <a name="start"></a>

# %% [markdown]
# ### 1.1 - Import relevant libraries <a name="import"></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# %%
# Retrieve dataframes stored in the EDA phase
# %store -r songs_data_df
# %store -r songs_data_stats_country
# %store -r songs_data_stats_region

# %% [markdown]
# ## 2 - Pre-processing <a name="import"></a>

# %% [markdown]
# ### 2.1 - Encode dummy variables for countries <a name="dummies"></a>

# %%
songs_data_stats_country.head()
# Out:
#      country  popularity  is_explicit    duration_ms  danceability    energy  \
# 0  Argentina   79.683897    30.206966  183280.889854      0.731863  0.686005
# 1  Australia   88.366650    36.016469  201002.420998      0.637842  0.622122
# 2    Austria   81.920905    30.942392  180443.483680      0.655136  0.653844
# 3    Belarus   63.649356    53.788417  159353.026372      0.685833  0.641679
# 4    Belgium   84.965859    26.959596  191042.988990      0.633213  0.648327
#
#           key  loudness      mode  speechiness  acousticness  \
# 0  625.037860 -5.248106  0.488339     0.088648      0.238702
# 1  473.669583 -6.857000  0.702213     0.071042      0.256684
# 2  501.647396 -6.832973  0.654763     0.096732      0.258236
# 3  549.700781 -6.880253  0.471650     0.117817      0.215263
# 4  489.050505 -6.599179  0.562828     0.078712      0.303627
#
#    instrumentalness  liveness   valence       tempo time_signature
# 0          0.004518  0.189616  0.644262  114.017433              4
# 1          0.008286  0.172767  0.497093  125.523188              4
# 2          0.019095  0.172822  0.516225  128.266714              4
# 3          0.064024  0.212752  0.501150  124.893331              4
# 4          0.027270  0.167556  0.521314  125.448159              4

# %%
df_encoded = pd.get_dummies(songs_data_stats_country.drop(['key', 'time_signature'], axis=1), columns=['country'], prefix=['country'])

# %%
df_encoded.head()
# Out:
#    popularity  is_explicit    duration_ms  danceability    energy  loudness  \
# 0   79.683897    30.206966  183280.889854      0.731863  0.686005 -5.248106
# 1   88.366650    36.016469  201002.420998      0.637842  0.622122 -6.857000
# 2   81.920905    30.942392  180443.483680      0.655136  0.653844 -6.832973
# 3   63.649356    53.788417  159353.026372      0.685833  0.641679 -6.880253
# 4   84.965859    26.959596  191042.988990      0.633213  0.648327 -6.599179
#
#        mode  speechiness  acousticness  instrumentalness  ...  country_Taiwan  \
# 0  0.488339     0.088648      0.238702          0.004518  ...           False
# 1  0.702213     0.071042      0.256684          0.008286  ...           False
# 2  0.654763     0.096732      0.258236          0.019095  ...           False
# 3  0.471650     0.117817      0.215263          0.064024  ...           False
# 4  0.562828     0.078712      0.303627          0.027270  ...           False
#
#    country_Thailand  country_Turkey  country_Ukraine  \
# 0             False           False            False
# 1             False           False            False
# 2             False           False            False
# 3             False           False            False
# 4             False           False            False
#
#    country_United Arab Emirates  country_United Kingdom  \
# 0                         False                   False
# 1                         False                   False
# 2                         False                   False
# 3                         False                   False
# 4                         False                   False
#
#    country_United States  country_Uruguay  country_Venezuela  country_Vietnam
# 0                  False            False              False            False
# 1                  False            False              False            False
# 2                  False            False              False            False
# 3                  False            False              False            False
# 4                  False            False              False            False
#
# [5 rows x 85 columns]

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 85 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   popularity                    72 non-null     float64
#  1   is_explicit                   72 non-null     float64
#  2   duration_ms                   72 non-null     float64
#  3   danceability                  72 non-null     float64
#  4   energy                        72 non-null     float64
#  5   loudness                      72 non-null     float64
#  6   mode                          72 non-null     float64
#  7   speechiness                   72 non-null     float64
#  8   acousticness                  72 non-null     float64
#  9   instrumentalness              72 non-null     float64
#  10  liveness                      72 non-null     float64
#  11  valence                       72 non-null     float64
#  12  tempo                         72 non-null     float64
#  13  country_Argentina             72 non-null     bool
#  14  country_Australia             72 non-null     bool
#  15  country_Austria               72 non-null     bool
#  16  country_Belarus               72 non-null     bool
#  17  country_Belgium               72 non-null     bool
#  18  country_Bolivia               72 non-null     bool
#  19  country_Brazil                72 non-null     bool
#  20  country_Bulgaria              72 non-null     bool
#  21  country_Canada                72 non-null     bool
#  22  country_Chile                 72 non-null     bool
#  23  country_Colombia              72 non-null     bool
#  24  country_Costa Rica            72 non-null     bool
#  25  country_Czechia               72 non-null     bool
#  26  country_Denmark               72 non-null     bool
#  27  country_Dominican Republic    72 non-null     bool
#  28  country_Ecuador               72 non-null     bool
#  29  country_Egypt                 72 non-null     bool
#  30  country_El Salvador           72 non-null     bool
#  31  country_Estonia               72 non-null     bool
#  32  country_Finland               72 non-null     bool
#  33  country_France                72 non-null     bool
#  34  country_Germany               72 non-null     bool
#  35  country_Greece                72 non-null     bool
#  36  country_Guatemala             72 non-null     bool
#  37  country_Honduras              72 non-null     bool
#  38  country_Hong Kong             72 non-null     bool
#  39  country_Hungary               72 non-null     bool
#  40  country_Iceland               72 non-null     bool
#  41  country_India                 72 non-null     bool
#  42  country_Indonesia             72 non-null     bool
#  43  country_Ireland               72 non-null     bool
#  44  country_Israel                72 non-null     bool
#  45  country_Italy                 72 non-null     bool
#  46  country_Japan                 72 non-null     bool
#  47  country_Kazakhstan            72 non-null     bool
#  48  country_Latvia                72 non-null     bool
#  49  country_Lithuania             72 non-null     bool
#  50  country_Luxembourg            72 non-null     bool
#  51  country_Malaysia              72 non-null     bool
#  52  country_Mexico                72 non-null     bool
#  53  country_Morocco               72 non-null     bool
#  54  country_Netherlands           72 non-null     bool
#  55  country_New Zealand           72 non-null     bool
#  56  country_Nicaragua             72 non-null     bool
#  57  country_Nigeria               72 non-null     bool
#  58  country_Norway                72 non-null     bool
#  59  country_Pakistan              72 non-null     bool
#  60  country_Panama                72 non-null     bool
#  61  country_Paraguay              72 non-null     bool
#  62  country_Peru                  72 non-null     bool
#  63  country_Philippines           72 non-null     bool
#  64  country_Poland                72 non-null     bool
#  65  country_Portugal              72 non-null     bool
#  66  country_Romania               72 non-null     bool
#  67  country_Saudi Arabia          72 non-null     bool
#  68  country_Singapore             72 non-null     bool
#  69  country_Slovakia              72 non-null     bool
#  70  country_South Africa          72 non-null     bool
#  71  country_South Korea           72 non-null     bool
#  72  country_Spain                 72 non-null     bool
#  73  country_Sweden                72 non-null     bool
#  74  country_Switzerland           72 non-null     bool
#  75  country_Taiwan                72 non-null     bool
#  76  country_Thailand              72 non-null     bool
#  77  country_Turkey                72 non-null     bool
#  78  country_Ukraine               72 non-null     bool
#  79  country_United Arab Emirates  72 non-null     bool
#  80  country_United Kingdom        72 non-null     bool
#  81  country_United States         72 non-null     bool
#  82  country_Uruguay               72 non-null     bool
#  83  country_Venezuela             72 non-null     bool
#  84  country_Vietnam               72 non-null     bool
# dtypes: bool(72), float64(13)
# memory usage: 12.5 KB

# %% [markdown]
# ### 2.2 - Scale data using StandardScaler <a name="scaling"></a>

# %%
# Since we already encoded the dummy variables, let's exclude Booleans from our DataFrame so we can apply the 
# StandardScaler without losing our country data.
df_no_bools = df_encoded.select_dtypes(exclude='bool')
df_bools = df_encoded.select_dtypes(include='bool')

# Make scaler object
scaler = StandardScaler()

# Fit the model to the data and transform it
scaled_df = scaler.fit_transform(df_no_bools)
scaled_df = pd.DataFrame(df_no_bools, columns=df_no_bools.columns)

# Combine the scaled data with df_bools to complete the DataFrame
df = pd.concat([scaled_df, df_bools], axis=1)

# %%
df.head()
# Out:
#    popularity  is_explicit    duration_ms  danceability    energy  loudness  \
# 0   79.683897    30.206966  183280.889854      0.731863  0.686005 -5.248106
# 1   88.366650    36.016469  201002.420998      0.637842  0.622122 -6.857000
# 2   81.920905    30.942392  180443.483680      0.655136  0.653844 -6.832973
# 3   63.649356    53.788417  159353.026372      0.685833  0.641679 -6.880253
# 4   84.965859    26.959596  191042.988990      0.633213  0.648327 -6.599179
#
#        mode  speechiness  acousticness  instrumentalness  ...  country_Taiwan  \
# 0  0.488339     0.088648      0.238702          0.004518  ...           False
# 1  0.702213     0.071042      0.256684          0.008286  ...           False
# 2  0.654763     0.096732      0.258236          0.019095  ...           False
# 3  0.471650     0.117817      0.215263          0.064024  ...           False
# 4  0.562828     0.078712      0.303627          0.027270  ...           False
#
#    country_Thailand  country_Turkey  country_Ukraine  \
# 0             False           False            False
# 1             False           False            False
# 2             False           False            False
# 3             False           False            False
# 4             False           False            False
#
#    country_United Arab Emirates  country_United Kingdom  \
# 0                         False                   False
# 1                         False                   False
# 2                         False                   False
# 3                         False                   False
# 4                         False                   False
#
#    country_United States  country_Uruguay  country_Venezuela  country_Vietnam
# 0                  False            False              False            False
# 1                  False            False              False            False
# 2                  False            False              False            False
# 3                  False            False              False            False
# 4                  False            False              False            False
#
# [5 rows x 85 columns]

# %% [markdown]
# ## 3 - Training <a name="train"></a>

# %% [markdown]
# ### 3.1 - Split data <a name="split"></a>
