# %% [markdown]
# ## First look at the dataset

# %% [markdown]
# ### Null values

# %% [markdown]
# #### Look at percentage of null values per column
# ```
# df.isna().sum()/df.shape[0]
# ```

# %% [markdown]
# #### Quick visualization of null values
# ```
# (df.isna().sum()/df.shape[0]).sort_values().plot(kind="bar")
# ```
# **Example:**
# ![image.png](attachment:image.png)
